# %%
import cPickle as pickle
import pandas
import numpy as np
from sklearn import metrics
import irm
# !pwd
# Out:
# /Users/jonas/projects/connectivitymotifs/paper/experiments/mouseretina

# %%
cd "/Users/jonas/projects/connectivitymotifs/paper/experiments/mouseretina"
# Out:
# /Users/jonas/projects/connectivitymotifs/paper/experiments/mouseretina

# %%
input_d = pickle.load(open("dummy.pickle"))

# %%
tgtdf = input_d['tgtdf']
aucsdf = input_d['aucsdf']

# %%
a = tgtdf.reset_index()
a[a['filename'] == 'data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000']
# Out:
#                                               filename  chain_i       ami  \
# 195  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...        0  0.426804
# 196  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...        1  0.426418
# 197  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...        2  0.441127
# 198  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...        3  0.434899
# 199  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...        4  0.443571
# 200  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...        5  0.432163
# 201  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...        6  0.439053
# 202  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...        7  0.433552
# 203  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...        8  0.432953
# 204  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...        9  0.440152
# 205  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...       10  0.437492
# 206  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...       11  0.434332
# 207  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...       12  0.431826
# 208  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...       13  0.428078
# 209  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...       14  0.421101
# 210  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...       15  0.440828
# 211  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...       16  0.428239
# 212  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...       17  0.429703
# 213  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...       18  0.434876
# 214  data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data...       19  0.417871
#
#      ami_coarse       ari  ari_coarse  cluster_n   jaccard  jaccard_coarse  \
# 195    0.232166  0.409607    0.205555         20  0.286231        0.196213
# 196    0.268067  0.404078    0.246080         17  0.282641        0.226732
# 197    0.259618  0.407079    0.243275         19  0.284956        0.224916
# 198    0.260511  0.406366    0.243142         19  0.284326        0.224194
# 199    0.257487  0.417198    0.215775         20  0.291918        0.200598
# 200    0.271608  0.402876    0.247838         17  0.281822        0.228729
# 201    0.244361  0.425360    0.214022         21  0.298356        0.199531
# 202    0.248396  0.420741    0.216462         19  0.294761        0.201443
# 203    0.263155  0.404065    0.245741         19  0.282598        0.226245
# 204    0.249292  0.420875    0.214630         20  0.294836        0.200090
# 205    0.250682  0.419373    0.216143         19  0.293731        0.201601
# 206    0.251475  0.402234    0.240069         19  0.281321        0.223800
# 207    0.263013  0.405154    0.245028         18  0.283445        0.225841
# 208    0.254506  0.401204    0.241857         19  0.280530        0.224944
# 209    0.245758  0.388756    0.235512         18  0.271367        0.223878
# 210    0.240761  0.418502    0.212640         20  0.293126        0.200067
# 211    0.268882  0.390985    0.251393         18  0.273095        0.234146
# 212    0.259224  0.399407    0.242628         18  0.279115        0.225139
# 213    0.240284  0.425648    0.210913         19  0.298425        0.196444
# 214    0.254619  0.381751    0.239626         17  0.266132        0.226883
#
#        n11          score                                               vars  \
# 195  14801  273645.824873                    x           z           y   ...
# 196  15582  268271.896876                    x           z           y   ...
# 197  15672  270263.829635                    x           z            y  ...
# 198  15535  269343.285515                    x           z            y  ...
# 199  14722  275103.874787                    x           z           y   ...
# 200  15700  268053.299178                    x           z           y   ...
# 201  14973  276032.968149                    x           z            y  ...
# 202  14904  275125.178026                    x           z            y  ...
# 203  15533  269285.843420                    x           z            y  ...
# 204  14868  276052.419145                    x           z            y  ...
# 205  14923  275070.487525                    x           z           y   ...
# 206  15669  269579.728646                    x           z            y  ...
# 207  15577  269349.256254                    x           z            y  ...
# 208  15639  268040.635772                    x           z            y  ...
# 209  15726  266375.513458                    x           z            y  ...
# 210  15001  274330.370798                    x           z            y  ...
# 211  15860  264374.387337                    x           z            y  ...
# 212  15528  267910.540292                    x           z            y  ...
# 213  14775  275634.871257                    x           z           y   ...
# 214  15561  265211.530660                    x           z           y   ...
#
#      scoreidx            model
# 195         7  srm_clist_xsoma
# 196        13  srm_clist_xsoma
# 197         8  srm_clist_xsoma
# 198        11  srm_clist_xsoma
# 199         4  srm_clist_xsoma
# 200        14  srm_clist_xsoma
# 201         1  srm_clist_xsoma
# 202         3  srm_clist_xsoma
# 203        12  srm_clist_xsoma
# 204         0  srm_clist_xsoma
# 205         5  srm_clist_xsoma
# 206         9  srm_clist_xsoma
# 207        10  srm_clist_xsoma
# 208        15  srm_clist_xsoma
# 209        17  srm_clist_xsoma
# 210         6  srm_clist_xsoma
# 211        19  srm_clist_xsoma
# 212        16  srm_clist_xsoma
# 213         2  srm_clist_xsoma
# 214        18  srm_clist_xsoma
#
# [20 rows x 14 columns]

# %%
# compute the variance and put it in a reasonable format
def vars_xyz_to_std(v):
    depth = np.mean(np.sqrt(v['x']))
    layer = np.mean(np.sqrt(v['y'] + v['z']))
    return pandas.Series({'depth_std': depth, 'layer_std' : layer})
vars = tgtdf['vars'].apply(lambda x : vars_xyz_to_std(x))
tgtdf['depth_std'] = vars['depth_std']
tgtdf['layer_std'] = vars['layer_std']

# %%
# perform the join
c = aucsdf.join(tgtdf)

# %%
d = c
#d = d[d['filename'].str.contains("retina.1")]
d = c[['retina.1' in s for s, y in c.index]]

# %%
d.head()
# Out:
#                                                                   auc distvar  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0        0.798857
#                                                     1        0.771818
#                                                     2        0.795967
#                                                     3        0.723369
#                                                     4        0.777250
#
#                                                                srm       ami  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0        False  0.183250
#                                                     1        False  0.196149
#                                                     2        False  0.187646
#                                                     3        False  0.187560
#                                                     4        False  0.184247
#
#                                                              ami_coarse  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0          0.193096
#                                                     1          0.190073
#                                                     2          0.187982
#                                                     3          0.199280
#                                                     4          0.190873
#
#                                                                   ari  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0        0.116296
#                                                     1        0.126009
#                                                     2        0.123853
#                                                     3        0.108872
#                                                     4        0.121231
#
#                                                              ari_coarse  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0          0.125572
#                                                     1          0.112358
#                                                     2          0.116700
#                                                     3          0.131282
#                                                     4          0.121629
#
#                                                              cluster_n  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0               17
#                                                     1               18
#                                                     2               18
#                                                     3               18
#                                                     4               17
#
#                                                               jaccard  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0        0.089089
#                                                     1        0.093478
#                                                     2        0.092125
#                                                     3        0.084488
#                                                     4        0.091161
#
#                                                              jaccard_coarse  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0              0.128823
#                                                     1              0.116116
#                                                     2              0.117928
#                                                     3              0.129794
#                                                     4              0.123114
#
#                                                               n11  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0        4272
#                                                     1        4178
#                                                     2        4091
#                                                     3        3957
#                                                     4        4178
#
#                                                                      score  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0       -234158.760661
#                                                     1       -231736.163411
#                                                     2       -231498.983188
#                                                     3       -233347.867884
#                                                     4       -232763.976439
#
#                                                                                                           vars  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0                          x           z           y   ...
#                                                     1                          x           z           y   ...
#                                                     2                          x           z           y   ...
#                                                     3                          x           z           y   ...
#                                                     4                          x           z           y   ...
#
#                                                              scoreidx model  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0              19  None
#                                                     1               3  None
#                                                     2               2  None
#                                                     3              13  None
#                                                     4               7  None
#
#                                                              depth_std  \
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0        13.252070
#                                                     1        13.376183
#                                                     2        12.797314
#                                                     3        12.895936
#                                                     4        12.956295
#
#                                                              layer_std
# filename                                            chain_i
# data/retina.1.bb.data-fixed_20_100-anneal_slow_1000 0        22.694408
#                                                     1        21.511076
#                                                     2        21.494607
#                                                     3        22.821845
#                                                     4        21.925124
#
# [5 rows x 17 columns]

# %%
e = aucsdf.reset_index()
f = e[e['filename'] == 'data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000']
print len(f)
# Out:
# 20

# %%
def g_auc(g):
    g = g.sort('pred_thold', ascending=False)
    # under estimate by using rectangles and anchoring left corner
    widths = np.diff(g['fp'])

    areas = g['tp'][:-1] * widths

    auc = np.sum(areas)

    return pandas.Series({'auc' : auc})

# %%
ground_truth_aucs = {}

for model in ['ld', 'bb']:
    tpl = pickle.load(open('truth.1.%s.predlinks.df.pickle' % model, 'r'))['df']

    tpl['tp'] = tpl['t_t'] / tpl['t_tot']
    tpl['fp'] = tpl['f_t'] / tpl['f_tot']
    truth_auc = g_auc(tpl)['auc']
    ground_truth_aucs[model] = truth_auc

# %%
df_vb = pickle.load(open("../others/vblpcm.results.pickle", 'r'))
df_vb_data = pickle.load(open("../others/data/data.pickle", 'r'))
vb_cells_with_data = df_vb_data['cells'][df_vb_data['have_edges_i']]
df_vb['ari'] = df_vb['assignments'].map(lambda x: metrics.adjusted_rand_score(irm.util.canonicalize_assignment(vb_cells_with_data['type_id']),
                                                                              irm.util.canonicalize_assignment(x)))

df_vb_conv = df_vb[df_vb['conv']]

# %%
def f(x):
    #print x.index.values
    c = vb_cells_with_data.copy()
    
    c['cluster'] = np.array(x['assignments'])
    a = c.groupby("cluster").var()
    return a
v = []

for row_i, row in df_vb.iterrows():
   
    v.append({'vars':  f(row)})
    
vb_vars_df = pandas.DataFrame(v)
    
    
df_vb['vars'] = vb_vars_df
df_vb.head()
# compute the variance and put it in a reasonable format
vars = df_vb['vars'].apply(vars_xyz_to_std)
df_vb['depth_std'] = vars['depth_std']
df_vb['layer_std'] = vars['layer_std']

# %%
d = d[d['distvar'] == 'xyz']
d_srm = d[d['srm']]
d_ld = d[d['srm'] == False]
d_bb = c[['bb' in s for s, y in c.index]]
d_clist = c[['1.clist' in s for s, y in c.index]]

f = pylab.figure(figsize=(10, 10))
ax = f.add_subplot(1, 1, 1)
ax.scatter(d_srm['ari'], d_srm['auc'], edgecolor='none', c='r', label="conn, dist, syn, depth")
ax.scatter(d_ld['ari'], d_ld['auc'], edgecolor='none', c='b', label="conn, dist")
ax.scatter(df_vb['ari'], df_vb['auc'], edgecolor='none', c='c', label="LPCM", s=30)

ax.scatter(d_bb['ari'], d_bb['auc'], edgecolor='none', c='g',  label="conn only")

ax.scatter(d_clist['ari'], d_clist['auc'], edgecolor='none', c='y', s=100, label="soma depth only")

ax.set_xlim(-0.01, 1.0)
ax.set_ylim(0.5, 1.0)
ax.grid()
ax.set_xlabel("Adjusted Rand Index (ARI)")
ax.set_ylabel("Area Under ROC Curve (AUC)")

for model_name, model, ls in [("human, with dist", 'ld', '-.'), ("human, no dist", 'bb', '--')]:
    ax.axhline(ground_truth_aucs[model], c='k', label=model_name, linestyle = ls)
    
ax.legend(loc="lower right")
f.savefig("/tmp/comparison.pdf")

# %%
# and then, in my nightmares, a bar graph for konrad
fig = pylab.figure(figsize=(6, 8))
ax1 = fig.add_subplot(2, 1, 1)
keys = ['human \n dist', 'human \n no dist', 'conn only', 'conn, dist',  'conn, dist\nsyn, depth', 'lpcm']
vals = [ground_truth_aucs['ld'], ground_truth_aucs['bb'], np.mean(d_simplebb['auc']), np.mean(d_ld['auc']), np.mean(d_srm['auc']), 
        np.mean(df_vb['auc'])]
vals_error = [0, 0, np.std(d_simplebb['auc']), np.std(d_ld['auc']), np.std(d_srm['auc']), np.std(df_vb['auc'])]
rects1 = ax1.bar(np.arange(len(keys)) + 0.5, vals, 0.8, color='w', yerr=vals_error)
ax1.set_ylabel('AUC')
ax1.set_ylim(0.0, 1.2)
ax1.axhline(1.0, linestyle='--')
ax1.set_xticks([])

ax2 = fig.add_subplot(2, 1, 2)
ari_vals = [1.0, 1.0, np.mean(d_bb['ari']), np.mean(d_ld['ari']), np.mean(d_srm['ari']), np.mean(df_vb['ari'])]
ari_vals_error = [0, 0, np.std(d_bb['ari']), np.std(d_ld['ari']), np.std(d_srm['ari']), np.std(df_vb['ari'])]
rects1 = ax2.bar(np.arange(len(keys)) + 0.5, ari_vals, 0.8,  color='w', yerr=ari_vals_error)
ax2.set_xticks(np.arange(len(keys)) + 0.5+0.4)
ax2.set_xticklabels(keys, rotation=90)

ax2.set_ylim(-0.1, 1.2)
ax2.axhline(1.0, linestyle='--')
ax2.set_ylabel("ARI")
fig.savefig('/tmp/bar.pdf')

# %%
# plot type 2 to make k-rad happy
# and then, in my nightmares, a bar graph for konrad
fig = pylab.figure(figsize=(12, 6))
ax1 = fig.add_subplot(1, 1, 1)
keys = ['human \n dist', 'human \n no dist', 'conn only', 'conn, dist',  'conn, dist\nsyn, depth', 'lpcm']
vals = [ground_truth_aucs['ld'], ground_truth_aucs['bb'], np.mean(d_simplebb['auc']), np.mean(d_ld['auc']), np.mean(d_srm['auc']), 
        np.mean(df_vb['auc'])]
vals_error = [0, 0, np.std(d_simplebb['auc']), np.std(d_ld['auc']), np.std(d_srm['auc']), np.std(df_vb['auc'])]
bar_space = 2.4
bar_width = 0.8
bpos = np.arange(len(keys))*bar_space + 0.5
bpos[0] += bar_width*0.5
bpos[1] += bar_width*0.6
rects1 = ax1.bar(bpos, vals, bar_width, color='r', yerr=vals_error)


ari_vals = [ np.mean(d_bb['ari']), np.mean(d_ld['ari']), np.mean(d_srm['ari']), np.mean(df_vb['ari'])]
ari_vals_error = [np.std(d_bb['ari']), np.std(d_ld['ari']), np.std(d_srm['ari']), np.std(df_vb['ari'])]
ax2 = ax1.twinx()
bpos = np.arange(len(keys))*bar_space + bar_width + 0.1  + 0.5
rects1 = ax2.bar(bpos[2:], 
                 ari_vals, bar_width,  color='b', yerr=ari_vals_error)

ax1.set_ylim(-0.02, 1.1)
ax2.set_ylim(-0.02, 1.1)

ax1.axhline(1.0, linestyle='--')
ax1.set_xticks(np.arange(len(keys)) * bar_space + bar_width + 0.55)
ax1.set_xticklabels(keys, rotation=90, fontsize=20)
ax1.set_xlim(0, 15)

ax2.set_ylabel('ARI', color='b', fontsize=30)
for tl in ax2.get_yticklabels():
    tl.set_color('b')
  
ax1.set_ylabel('AUC', color='R', fontsize=30)
for tl in ax1.get_yticklabels():
    tl.set_color('r')
fig.tight_layout()
fig.savefig("allmethods.ari_auc.pdf")

# %%
# compute the best chain : 
a = d_srm.reset_index()
b = a.groupby(['filename', 'chain_i']).mean()
c = b.sort("ari", ascending=False)
c.head()
# Out:
#                                                                                            auc  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15       0.896901
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18       0.896758
#                                                                              6        0.897575
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16       0.897493
#                                                                              5        0.898561
#
#                                                                                        srm  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15       True
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18       True
#                                                                              6        True
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16       True
#                                                                              5        True
#
#                                                                                            ami  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15       0.456304
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18       0.434876
#                                                                              6        0.439053
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16       0.443885
#                                                                              5        0.445864
#
#                                                                                       ami_coarse  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15         0.240620
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18         0.240284
#                                                                              6          0.244361
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16         0.251158
#                                                                              5          0.262367
#
#                                                                                            ari  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15       0.462856
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18       0.425648
#                                                                              6        0.425360
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16       0.423840
#                                                                              5        0.423064
#
#                                                                                       ari_coarse  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15         0.162004
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18         0.210913
#                                                                              6          0.214022
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16         0.216224
#                                                                              5          0.220007
#
#                                                                                       cluster_n  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15              19
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18              19
#                                                                              6               21
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16              22
#                                                                              5               19
#
#                                                                                        jaccard  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15       0.327185
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18       0.298425
#                                                                              6        0.298356
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16       0.297103
#                                                                              5        0.296643
#
#                                                                                       jaccard_coarse  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15             0.157334
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18             0.196444
#                                                                              6              0.199531
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16             0.200507
#                                                                              5              0.203975
#
#                                                                                         n11  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15       14119
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18       14775
#                                                                              6        14973
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16       14862
#                                                                              5        15038
#
#                                                                                               score  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15       275024.529538
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18       275634.871257
#                                                                              6        276032.968149
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16       276116.450670
#                                                                              5        276004.809569
#
#                                                                                       scoreidx  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15              0
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18              2
#                                                                              6               1
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16              0
#                                                                              5               1
#
#                                                                                       depth_std  \
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15        7.447901
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18        9.825360
#                                                                              6         8.369991
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16        9.134416
#                                                                              5         8.390067
#
#                                                                                       layer_std
# filename                                                                     chain_i
# data/retina.1.srm_clist_xsoma.3.1.xyz.1.2.data-fixed_20_100-anneal_slow_1000 15       34.274542
# data/retina.1.srm_clist_xsoma.3.0.xyz.0.2.data-fixed_20_100-anneal_slow_1000 18       33.784155
#                                                                              6        33.475891
# data/retina.1.srm_clist_xsoma.3.1.xyz.0.2.data-fixed_20_100-anneal_slow_1000 16       34.054052
#                                                                              5        34.056878
#
# [5 rows x 14 columns]

# %%
truth_space_var = df_vb_data['cells'].groupby('type_id').var()

truth_space_depth_std = np.sqrt(truth_space_var['x'])
truth_space_layer_std = np.sqrt(truth_space_var['y'] + truth_space_var['z'])
truth_space_df = pandas.DataFrame({'layer_std' : truth_space_layer_std, 'depth_std' : truth_space_depth_std})
print truth_space_df.mean()
# Out:
# depth_std     1.981348
# layer_std    34.349065
# dtype: float64

# %%
data_sets = [truth_space_df, d_bb, d_ld,  d_srm, df_vb]
dists  = np.array([(np.mean(x['layer_std']), np.std(x['layer_std'])) for x in data_sets])
fig = pylab.figure(figsize=(8, 6))
ax1 = fig.add_subplot(1, 1, 1)
keys = ['human', 'conn only', 'conn, dist',  'conn, dist\nsyn, depth', 'lpcm', ]
vals = dists[:, 0]
vals_error = dists[:, 1]
bar_space = 2.4
bar_width = 0.8
rects1 = ax1.bar(np.arange(len(keys))*bar_space + 0.5, vals, bar_width, color='r', yerr=vals_error)


ax2 = ax1.twinx()
dists  = np.array([(np.mean(x['depth_std']), np.std(x['depth_std'])) for x in data_sets])

rects1 = ax2.bar(np.arange(len(keys))*bar_space + bar_width + 0.1  + 0.5, dists[:, 0], bar_width,  color='b', yerr=dists[:, 1])


ax1.set_xticks(np.arange(len(keys)) * bar_space + bar_width + 0.55)
ax1.set_xticklabels(keys, rotation=90, fontsize=20)
#ax1.set_xlim(0, 10)

ax2.set_ylabel('layer type extent', color='b', fontsize=30)
for tl in ax2.get_yticklabels():
    tl.set_color('b')
  
ax1.set_ylabel('depth type extent', color='R', fontsize=30)
for tl in ax1.get_yticklabels():
    tl.set_color('r')
fig.tight_layout()
fig.savefig("allmethods.spatial.pdf")
